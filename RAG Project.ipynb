# %%
#installing pdfquery, library that helps extract data from PDF files
# !pip install pdfquery
# Out:
# Requirement already satisfied: pdfquery in c:\users\jyothi\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: cssselect>=0.7.1 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (1.2.0)
# Requirement already satisfied: chardet in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (4.0.0)
# Requirement already satisfied: lxml>=3.0 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (4.9.2)
# Requirement already satisfied: pdfminer.six in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (20240706)
# Requirement already satisfied: pyquery>=1.2.2 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (2.0.1)
# Requirement already satisfied: roman>=1.4.0 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfquery) (5.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfminer.six->pdfquery) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\jyothi\anaconda3\lib\site-packages (from pdfminer.six->pdfquery) (39.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\jyothi\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->pdfquery) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\jyothi\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pdfquery) (2.21)

# %%
#importing all the neccessary libraries
import pdfquery                     
from collections import Counter     
import math
import requests
import json
import re

# %%
#defining a funciton to calculate the cosine similarity between the query entered by used and relevant document from the corpus
def cosine_similarity(query, document):
    #tokenization
    query_tokens = query.lower().split(" ")
    document_tokens = document.lower().split(" ")
    
    #counter for query and document
    query_counter = Counter(query_tokens)
    document_counter = Counter(document_tokens)
    
    #calculating dot prod
    dot_product = sum(query_counter[token] * document_counter[token] for token in query_counter.keys())
    
    #calculating magnitudes
    query_magnitude = math.sqrt(sum(query_counter[token]**2 for token in query_counter))
    document_magnitude = math.sqrt(sum(document_counter[token]**2 for token in document_counter))
    
    #calculating similarity
    #incase (query_magnitude*document_magnitude)=0, the value of similarity becomes 0 else as calculated
    similarity = dot_product/(query_magnitude*document_magnitude) if query_magnitude*document_magnitude!=0 else 0
    
    return similarity

# %%
#function to return a document similar to the query from the corpus
def return_response(query, corpus):
    similarities = []
    for doc in corpus:
        similarity = cosine_similarity(query, doc)      #calls the cosine_similarity function
        similarities.append(similarity)                 #adds the calculated similarity score to the similarities list
        
    return corpus[similarities.index(max(similarities))]

# %%
#creating a infinite loop until the user wants to terminate the program
while(True):
    print("Choose the RAG model you want to interact with: ")
    print("1. Data Structures RAG Model")
    print("2. Programming Paradigms RAG Model")
    print("3. Computer Networks RAG Model")
    print("4. Terminate the program")
    choice = int(input("Enter your choice: "))        #accepting the model choice of the user from the menu displayed
    
    pdf = []
    if(choice==1):
        pdf = pdfquery.PDFQuery("Data Structures Corpus.pdf")
    elif(choice==2):
        pdf = pdfquery.PDFQuery("Programming Paradigms.pdf")
    elif(choice==3):
        pdf = pdfquery.PDFQuery("Computer Networks.pdf")
    else:
        print("Closing Program.. Thank you!!")
        break
        
    
    pdf.load()
    # Extract all text elements
    text_elements = pdf.pq('LTTextLineHorizontal')
    text = " ".join([t.text for t in text_elements])  # Combine all text

    # Split text into sentences using regex
    corpus = re.split(r'(?<=[.!?]) +', text)
   
    while(True):
        print("Enter Quit to exit from the model")
        user_query = input(">>>")
        
        relevant_document = return_response(user_query,corpus)

        if user_query.lower() == 'quit':
            print("\n\n")
            print(f"{'=' * 30}")
            break
        full_response = []

        prompt="""
        You are a bot that makes recommendations for activities and lifestyle changes.
        You answer only in 70 words making sure you encourage the user.
        This is the recommended activity: {relevant_document}
        The user input is: {user_input}
        Compile a recommendation to the user based on the recommended activity and the user input.
        """

        url = "http://localhost:11434/api/generate"

        #now reuqesting above URl which is running locally to execute below command
        #we are using json format for making the request

        data = {
            "model": "llama3",
            "prompt": prompt.format(user_input=user_query, relevant_document=relevant_document)
        }

        headers = {'Content-Type': 'application/json'}

        response = requests.post(url, data=json.dumps(data), headers=headers, stream=True)


        try:
            for line in response.iter_lines():
            #filter out keep-alive new lines
                if line:
                    decoded_line = json.loads(line.decode('utf-8'))
                    full_response.append(decoded_line['response'])
        finally:
            response.close()

        print(''.join(full_response))
        print(f"{'*' * 30}")
# Out:
# Choose the RAG model you want to interact with:
# 1. Data Structures RAG Model
# 2. Programming Paradigms RAG Model
# 3. Computer Networks RAG Model
# 4. Terminate the program
# Enter your choice: 1
# Enter Quit to exit from the model
# >>>what are strings?
# I'm excited to help you explore the world of coding! Strings, my friend, are the building blocks of programming. They're sequences of characters used for text manipulation. To get started, I recommend practicing with some fun string exercises, such as reversing a sentence or finding specific words within a text. This will help you develop your problem-solving skills and get comfortable working with strings. You got this!
# ******************************
# Enter Quit to exit from the model
# >>>which structure consists of vertices and edges?
# I love that you're curious about graphs! Since you asked, "which structure consists of vertices and edges?", I'm excited to recommend an activity for you.
#
# Why not try creating your own graph? You can use online tools or even draw it by hand. Visualize relationships between people, places, or ideas. It's a great way to develop problem-solving skills and think creatively. Give it a try and see how it sparks new connections in your mind!
# ******************************
# Enter Quit to exit from the model
# >>>quit
#
#
#
# ==============================
# Choose the RAG model you want to interact with:
# 1. Data Structures RAG Model
# 2. Programming Paradigms RAG Model
# 3. Computer Networks RAG Model
# 4. Terminate the program
# Enter your choice: 2
# Enter Quit to exit from the model
# >>>which technique divides a program's instructions among multiple processors to speed up execution?
# I love seeing you explore computer science concepts! Great job recognizing Parallel Processing as a way to accelerate program execution. To take your understanding to the next level, I recommend experimenting with parallel processing in a coding project or even contributing to an open-source project that utilizes this technique. Your skills will surely speed up and shine!
# ******************************
# Enter Quit to exit from the model
# >>>what is declarative programming?
# I love your curiosity! Declarative programming is a game-changer. By focusing on what you want to achieve, rather than how to achieve it, you'll become more efficient and creative in your problem-solving. Give it a try and discover a new way of thinking! Start with simple exercises or tutorials to get comfortable with the syntax and logic. You got this!
# ******************************
# Enter Quit to exit from the model
# >>>quit
#
#
#
# ==============================
# Choose the RAG model you want to interact with:
# 1. Data Structures RAG Model
# 2. Programming Paradigms RAG Model
# 3. Computer Networks RAG Model
# 4. Terminate the program
# Enter your choice: 3
# Enter Quit to exit from the model
# >>>what are the various networking devices?
# I'm thrilled you're interested in exploring Network Protocols! Based on your curiosity about various networking devices, I highly recommend diving into the world of routers, switches, modems, firewalls, and access points. These devices play a crucial role in facilitating data transmission and communication. By learning about them, you'll gain a deeper understanding of how protocols work together to ensure seamless network operations!
# ******************************
# Enter Quit to exit from the model
# >>>what are the different network protocols?
# I'm excited to help you explore Network Architectures! Given your interest in learning about different network protocols, I recommend diving into the world of networking architectures. Start by understanding the client-server model, where devices communicate with a central server, and then move on to peer-to-peer models, where devices act as both clients and servers. This will give you a solid foundation to understand various network protocols like TCP/IP, DNS, and HTTP. Get ready to geek out and expand your knowledge!
# ******************************
# Enter Quit to exit from the model
# >>>quit
#
#
#
# ==============================
# Choose the RAG model you want to interact with:
# 1. Data Structures RAG Model
# 2. Programming Paradigms RAG Model
# 3. Computer Networks RAG Model
# 4. Terminate the program
# Enter your choice: 4
# Closing Program.. Thank you!!
